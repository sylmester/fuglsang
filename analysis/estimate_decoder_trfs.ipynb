# %% [markdown]
# # Estimating TRFs for decoder model ot reconstruct envelope from EEG

# %%
import sys
# Add parent directory to path to import file_paths module
sys.path.insert(0, '..')
import file_paths
import helper_functions

import eelbrain

SUBJECTS = helper_functions.get_subjects()

# %%
# Loop through subjects to estimate TRFs

for SUBJECT in SUBJECTS:
    print("-" * 50)
    print(f"Processing subject {SUBJECT}...")

    # Check if all TRF files already exist
    trf_dir = file_paths.TRF_DIR / SUBJECT
    trf_attended_path = trf_dir / f"{SUBJECT}_attended_decoder_trf.pickle"
    trf_unattended_path = trf_dir / f"{SUBJECT}_unattended_decoder_trf.pickle"
    
    if all([trf_attended_path.exists(), trf_unattended_path.exists()]):
        print(f"All TRF files for {SUBJECT} already exist, skipping.")
        continue

    # Load EEG data from pickle files
    eeg_path = file_paths.EEG_DIR / SUBJECT / f"{SUBJECT}_eeg.pickle"
    eeg = eelbrain.load.unpickle(eeg_path)

    # Load envelope data (all 4 versions)
    attended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_attended_envelope.pickle"
    unattended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_unattended_envelope.pickle"
    
    attended_envelope = eelbrain.load.unpickle(attended_envelope_path)
    unattended_envelope = eelbrain.load.unpickle(unattended_envelope_path)

    print(f"EEG: {eeg}")
    print(f"Attended envelope: {attended_envelope}")
    print(f"Unattended envelope: {unattended_envelope}")

    # Estimate TRFs for attended and unattended conditions using boosting
    print("Estimating attended TRF...")
    trf_attended = eelbrain.boosting(
            attended_envelope,
            eeg,
            -1.000,
            0.100, 
            error='l1',
            basis=0.050,
            partitions=5,
            test=1,
            selective_stopping=True
        )
    
    print("Estimating unattended TRF...")
    trf_unattended = eelbrain.boosting(
            unattended_envelope,
            eeg,
            -1.000,
            0.100, 
            error='l1',
            basis=0.050,
            partitions=5,
            test=1,
            selective_stopping=True
        )
    
    # Save all 4 TRFs
    trf_dir.mkdir(exist_ok=True, parents=True)
    
    eelbrain.save.pickle(trf_attended, trf_attended_path)
    eelbrain.save.pickle(trf_unattended, trf_unattended_path)


    print(f"Saved attended decoder TRF to {trf_attended_path}")
    print(f"Saved unattended decoder TRF to {trf_unattended_path}")
# Out:
# --------------------------------------------------
# Processing subject S1...
# All TRF files for S1 already exist, skipping.
# --------------------------------------------------
# Processing subject S2...
# All TRF files for S2 already exist, skipping.
# --------------------------------------------------
# Processing subject S3...
# All TRF files for S3 already exist, skipping.
# --------------------------------------------------
# Processing subject S4...
# All TRF files for S4 already exist, skipping.
# --------------------------------------------------
# Processing subject S5...
# All TRF files for S5 already exist, skipping.
# --------------------------------------------------
# Processing subject S6...
# All TRF files for S6 already exist, skipping.
# --------------------------------------------------
# Processing subject S7...
# All TRF files for S7 already exist, skipping.
# --------------------------------------------------
# Processing subject S8...
# All TRF files for S8 already exist, skipping.
# --------------------------------------------------
# Processing subject S9...
# All TRF files for S9 already exist, skipping.
# --------------------------------------------------
# Processing subject S10...
# All TRF files for S10 already exist, skipping.
# --------------------------------------------------
# Processing subject S11...
# All TRF files for S11 already exist, skipping.
# --------------------------------------------------
# Processing subject S12...
# All TRF files for S12 already exist, skipping.
# --------------------------------------------------
# Processing subject S13...
# All TRF files for S13 already exist, skipping.
# --------------------------------------------------
# Processing subject S14...
# All TRF files for S14 already exist, skipping.
# --------------------------------------------------
# Processing subject S15...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S15/S15_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S15/S15_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S16...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S16/S16_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S16/S16_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S17...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S17/S17_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S17/S17_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S18...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S18/S18_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S18/S18_unattended_decoder_trf.pickle
