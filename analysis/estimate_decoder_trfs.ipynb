# %% [markdown]
# # Estimating TRFs for decoder model ot reconstruct envelope from EEG

# %%
import sys
# Add parent directory to path to import file_paths module
sys.path.insert(0, '..')
import file_paths
import helper_functions

import eelbrain

SUBJECTS = helper_functions.get_subjects()

# %%
# Loop through subjects to estimate TRFs

for SUBJECT in SUBJECTS:
    print("-" * 50)
    print(f"Processing subject {SUBJECT}...")

    # Check if all TRF files already exist
    trf_dir = file_paths.TRF_DIR / SUBJECT
    trf_attended_path = trf_dir / f"{SUBJECT}_attended_decoder_trf.pickle"
    trf_unattended_path = trf_dir / f"{SUBJECT}_unattended_decoder_trf.pickle"
    
    #if all([trf_attended_path.exists(), trf_unattended_path.exists()]):
    #    print(f"All TRF files for {SUBJECT} already exist, skipping.")
    #    continue

    # Load EEG data from pickle files
    eeg_path = file_paths.EEG_DIR / SUBJECT / f"{SUBJECT}_eeg.pickle"
    eeg = eelbrain.load.unpickle(eeg_path)

    # Load envelope data (all 4 versions)
    attended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_attended_envelope.pickle"
    unattended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_unattended_envelope.pickle"
    
    attended_envelope = eelbrain.load.unpickle(attended_envelope_path)
    unattended_envelope = eelbrain.load.unpickle(unattended_envelope_path)

    print(f"EEG: {eeg}")
    print(f"Attended envelope: {attended_envelope}")
    print(f"Unattended envelope: {unattended_envelope}")

    # Estimate TRFs for attended and unattended conditions using boosting
    print("Estimating attended TRF...")
    trf_attended = eelbrain.boosting(
            attended_envelope,
            eeg,
            -1.000,
            0.100, 
        )
    
    print("Estimating unattended TRF...")
    trf_unattended = eelbrain.boosting(
            unattended_envelope,
            eeg,
            -1.000,
            0.100, 
        )
    
    # Save all 4 TRFs
    trf_dir.mkdir(exist_ok=True, parents=True)
    
    eelbrain.save.pickle(trf_attended, trf_attended_path)
    eelbrain.save.pickle(trf_unattended, trf_unattended_path)


    print(f"Saved attended decoder TRF to {trf_attended_path}")
    print(f"Saved unattended decoder TRF to {trf_unattended_path}")
# Out:
# --------------------------------------------------
# Processing subject S1...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S1/S1_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S1/S1_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S2...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S2/S2_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S2/S2_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S3...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S3/S3_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S3/S3_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S4...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S4/S4_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S4/S4_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S5...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S5/S5_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S5/S5_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S6...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S6/S6_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S6/S6_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S7...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S7/S7_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S7/S7_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S8...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S8/S8_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S8/S8_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S9...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S9/S9_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S9/S9_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S10...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S10/S10_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S10/S10_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S11...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S11/S11_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S11/S11_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S12...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S12/S12_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S12/S12_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S13...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S13/S13_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S13/S13_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S14...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S14/S14_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S14/S14_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S15...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S15/S15_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S15/S15_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S16...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S16/S16_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S16/S16_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S17...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S17/S17_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S17/S17_unattended_decoder_trf.pickle
# --------------------------------------------------
# Processing subject S18...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S18/S18_attended_decoder_trf.pickle
# Saved unattended decoder TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S18/S18_unattended_decoder_trf.pickle
